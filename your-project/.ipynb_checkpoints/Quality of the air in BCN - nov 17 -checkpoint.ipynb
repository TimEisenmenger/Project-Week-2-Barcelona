# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Raw-data-overview" data-toc-modified-id="Raw-data-overview-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Raw data overview</a></span></li><li><span><a href="#Data-cleaned-from-special-characters-on-NaN" data-toc-modified-id="Data-cleaned-from-special-characters-on-NaN-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data cleaned from special characters on NaN</a></span><ul class="toc-item"><li><span><a href="#Import-data-and-substitute-al-misssing-values-in-one-value-(NaN)" data-toc-modified-id="Import-data-and-substitute-al-misssing-values-in-one-value-(NaN)-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Import data and substitute al misssing values in one value (NaN)</a></span></li><li><span><a href="#Changing-name-of-columns" data-toc-modified-id="Changing-name-of-columns-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Changing name of columns</a></span></li><li><span><a href="#Creating-new-variable-Time-and-Date-and-formating-it" data-toc-modified-id="Creating-new-variable-Time-and-Date-and-formating-it-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Creating new variable Time and Date and formating it</a></span><ul class="toc-item"><li><span><a href="#Reformat-time,-date-variables-and-create-a-Week-Day-column" data-toc-modified-id="Reformat-time,-date-variables-and-create-a-Week-Day-column-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Reformat time, date variables and create a Week Day column</a></span></li></ul></li><li><span><a href="#Droping-column-Latitude,-Longitude-and-Genrated" data-toc-modified-id="Droping-column-Latitude,-Longitude-and-Genrated-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Droping column Latitude, Longitude and Genrated</a></span></li><li><span><a href="#Cleaning-colum-Station-to-remove-Barcelona" data-toc-modified-id="Cleaning-colum-Station-to-remove-Barcelona-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Cleaning colum Station to remove Barcelona</a></span></li><li><span><a href="#Drop-duplicates" data-toc-modified-id="Drop-duplicates-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Drop duplicates</a></span></li><li><span><a href="#What-we-do-with-the-missing-values?" data-toc-modified-id="What-we-do-with-the-missing-values?-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>What we do with the missing values?</a></span><ul class="toc-item"><li><span><a href="#NaN-in-variables-related-with-time" data-toc-modified-id="NaN-in-variables-related-with-time-2.7.1"><span class="toc-item-num">2.7.1&nbsp;&nbsp;</span>NaN in variables related with time</a></span><ul class="toc-item"><li><span><a href="#Check-all-variables-related-to-time-together" data-toc-modified-id="Check-all-variables-related-to-time-together-2.7.1.1"><span class="toc-item-num">2.7.1.1&nbsp;&nbsp;</span>Check all variables related to time together</a></span></li><li><span><a href="#Delete-columns-of-the-hour-taken-the-measure-and-keep-the-generated-time" data-toc-modified-id="Delete-columns-of-the-hour-taken-the-measure-and-keep-the-generated-time-2.7.1.2"><span class="toc-item-num">2.7.1.2&nbsp;&nbsp;</span>Delete columns of the hour taken the measure and keep the generated time</a></span></li></ul></li><li><span><a href="#Checking-again-our-NaN-table" data-toc-modified-id="Checking-again-our-NaN-table-2.7.2"><span class="toc-item-num">2.7.2&nbsp;&nbsp;</span>Checking again our NaN table</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Project Week 2: The quality of air in Barcelona (November 2018)

# %% [markdown]
# ## Raw data overview

# %%
import pandas as pd
import numpy as np
import os

# %%
air_quality = pd.read_csv("data/air-quality-nov-2017.csv")

# %%
air_quality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5744 entries, 0 to 5743
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Station       5744 non-null   object
#  1   Air Quality   5744 non-null   object
#  2   Longitude     5744 non-null   float64
#  3   Latitude      5744 non-null   float64
#  4   O3 Hour       4268 non-null   object
#  5   O3 Quality    4268 non-null   object
#  6   O3 Value      4101 non-null   float64
#  7   NO2 Hour      5689 non-null   object
#  8   NO2 Quality   5689 non-null   object
#  9   NO2 Value     5460 non-null   float64
#  10  PM10 Hour     3722 non-null   object
#  11  PM10 Quality  3722 non-null   object
#  12  PM10 Value    3647 non-null   float64
#  13  Generated     5744 non-null   object
#  14  Date Time     5744 non-null   int64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 673.2+ KB

# %% [markdown]
# We can see we have 5744 entries in total. As a descriptive variable we will consider Station to be used to display the missing values per column per station. We have seen already looking a bit trought de data that might a pattern of missing values fro certain stations and certain pollutants.

# %% [markdown]
# We are gonna display a table with missing values x column and x station.

# %%
#missing values in station x variable
nan_sants=air_quality[air_quality["Station"]=='Barcelona - Sants'].isnull().sum()
nan_eixample=air_quality[air_quality["Station"]=='Barcelona - Eixample'].isnull().sum()
nan_gracia=air_quality[air_quality["Station"]=='Barcelona - Gràcia'].isnull().sum()
nan_ciutadella=air_quality[air_quality["Station"]=='Barcelona - Ciutadella'].isnull().sum()
nan_valldhebron=air_quality[air_quality["Station"]=='Barcelona - Vall Hebron'].isnull().sum()
nan_palaureial=air_quality[air_quality["Station"]=='Barcelona - Palau Reial'].isnull().sum()
nan_poblenou=air_quality[air_quality["Station"]=='Barcelona - Poblenou'].isnull().sum()
nan_fabra=air_quality[air_quality["Station"]=='Barcelona - Observ Fabra'].isnull().sum()

# %%
nan_x_station= [nan_sants,nan_eixample,nan_gracia,nan_ciutadella,nan_valldhebron,nan_palaureial,nan_poblenou,nan_fabra]

stations = list(air_quality["Station"].unique())

nan_matrix_x_column_x_station= pd.concat(nan_x_station, axis=1)

nan_matrix_x_column_x_station.columns=stations
nan_matrix_x_column_x_station = nan_matrix_x_column_x_station.drop("Station")

nan_matrix_x_column_x_station =nan_matrix_x_column_x_station.transpose()
nan_matrix_x_column_x_station
# Out:
#                           Air Quality  Longitude  Latitude  O3 Hour  \
# Barcelona - Sants                   0          0         0      718
# Barcelona - Eixample                0          0         0        7
# Barcelona - Gràcia                  0          0         0       11
# Barcelona - Ciutadella              0          0         0        4
# Barcelona - Vall Hebron             0          0         0        6
# Barcelona - Palau Reial             0          0         0        7
# Barcelona - Poblenou                0          0         0      718
# Barcelona - Observ Fabra            0          0         0        5
#
#                           O3 Quality  O3 Value  NO2 Hour  NO2 Quality  \
# Barcelona - Sants                718       718         7            7
# Barcelona - Eixample               7        73         7            7
# Barcelona - Gràcia                11        74        11           11
# Barcelona - Ciutadella             4        17         4            4
# ...

# %% [markdown]
# If we look, for instance, to Gràcia in the O3 variables, it shows 11 missing values fpr hour and quality and 74 for value. That makes no sense as if there is a measure of one pollutant we should be able to see the same amount of missing value for the three variables.
#
# Looking at this on the data set we realized that certain entries are consider as values and they should be considered as miss values.
#
# Those are the characters considered as values and not missing values:<b>
#
# **"n/a","na","--"**

# %% [markdown]
# ## Data cleaned from special characters on NaN

# %% [markdown]
# ### Import data and substitute al misssing values in one value (NaN)

# %% [markdown]
# This time we will import the initial dataset considering those characters as missing values.

# %%
#Some of the missing values where looking like this characters
missing_values= ["n/a","na","--"]

# %%
air_quality = pd.read_csv("data/air-quality-nov-2017.csv",na_values=missing_values)

# %%
air_quality.head(15)
# Out:
#                      Station Air Quality  Longitude  Latitude O3 Hour  \
# 0          Barcelona - Sants        Good     2.1331   41.3788     NaN
# 1       Barcelona - Eixample    Moderate     2.1538   41.3853      0h
# 2         Barcelona - Gràcia        Good     2.1534   41.3987      0h
# 3     Barcelona - Ciutadella        Good     2.1874   41.3864      0h
# 4    Barcelona - Vall Hebron        Good     2.1480   41.4261      0h
# 5    Barcelona - Palau Reial        Good     2.1151   41.3875     23h
# 6       Barcelona - Poblenou        Good     2.2045   41.4039     NaN
# 7   Barcelona - Observ Fabra        Good     2.1239   41.4183     23h
# 8          Barcelona - Sants        Good     2.1331   41.3788     NaN
# 9       Barcelona - Eixample        Good     2.1538   41.3853      0h
# 10        Barcelona - Gràcia        Good     2.1534   41.3987      0h
# 11    Barcelona - Ciutadella        Good     2.1874   41.3864      0h
# ...

# %%
air_quality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5744 entries, 0 to 5743
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Station       5744 non-null   object
#  1   Air Quality   5583 non-null   object
#  2   Longitude     5744 non-null   float64
#  3   Latitude      5744 non-null   float64
#  4   O3 Hour       4268 non-null   object
#  5   O3 Quality    4101 non-null   object
#  6   O3 Value      4101 non-null   float64
#  7   NO2 Hour      5689 non-null   object
#  8   NO2 Quality   5460 non-null   object
#  9   NO2 Value     5460 non-null   float64
#  10  PM10 Hour     3722 non-null   object
#  11  PM10 Quality  3647 non-null   object
#  12  PM10 Value    3647 non-null   float64
#  13  Generated     5744 non-null   object
#  14  Date Time     5744 non-null   int64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 673.2+ KB

# %%
#We still have a lot of null values but we will go more in details later
air_quality.isnull().sum()
# Out:
# Station            0
# Air Quality      161
# Longitude          0
# Latitude           0
# O3 Hour         1476
# O3 Quality      1643
# O3 Value        1643
# NO2 Hour          55
# NO2 Quality      284
# NO2 Value        284
# PM10 Hour       2022
# PM10 Quality    2097
# PM10 Value      2097
# Generated          0
# Date Time          0
# dtype: int64

# %% [markdown]
# ### Changing name of columns

# %%
air_quality = air_quality.rename(columns={"O3 Value":"O3 µg/m3","NO2 Value":"NO2 µg/m3","PM10 Value":"PM10 µg/m3"})

# %%
air_quality.head()
# Out:
#                    Station Air Quality  Longitude  Latitude O3 Hour  \
# 0        Barcelona - Sants        Good     2.1331   41.3788     NaN
# 1     Barcelona - Eixample    Moderate     2.1538   41.3853      0h
# 2       Barcelona - Gràcia        Good     2.1534   41.3987      0h
# 3   Barcelona - Ciutadella        Good     2.1874   41.3864      0h
# 4  Barcelona - Vall Hebron        Good     2.1480   41.4261      0h
#
#   O3 Quality  O3 µg/m3 NO2 Hour NO2 Quality  NO2 µg/m3 PM10 Hour PM10 Quality  \
# 0        NaN       NaN       0h        Good       84.0       NaN          NaN
# 1       Good       1.0       0h    Moderate      113.0        0h         Good
# 2       Good      10.0       0h        Good       73.0       NaN          NaN
# 3       Good       2.0       0h        Good       86.0       NaN          NaN
# 4       Good       7.0       0h        Good       69.0       NaN          NaN
#
#    PM10 µg/m3        Generated   Date Time
# 0         NaN  01/11/2018 0:00  1541027104
# ...

# %% [markdown]
# ### Creating new variable Time and Date and formating it

# %%
air_quality[['Generated Date','Generated Time']] = air_quality.Generated.str.split(expand=True)
air_quality
# Out:
#                        Station Air Quality  Longitude  Latitude O3 Hour  \
# 0            Barcelona - Sants        Good     2.1331   41.3788     NaN
# 1         Barcelona - Eixample    Moderate     2.1538   41.3853      0h
# 2           Barcelona - Gràcia        Good     2.1534   41.3987      0h
# 3       Barcelona - Ciutadella        Good     2.1874   41.3864      0h
# 4      Barcelona - Vall Hebron        Good     2.1480   41.4261      0h
# ...                        ...         ...        ...       ...     ...
# 5739    Barcelona - Ciutadella        Good     2.1874   41.3864     22h
# 5740   Barcelona - Vall Hebron        Good     2.1480   41.4261     22h
# 5741   Barcelona - Palau Reial        Good     2.1151   41.3875     22h
# 5742      Barcelona - Poblenou        Good     2.2045   41.4039     NaN
# 5743  Barcelona - Observ Fabra        Good     2.1239   41.4183     22h
#
#      O3 Quality  O3 Value NO2 Hour NO2 Quality  NO2 Value PM10 Hour  \
# ...

# %% [markdown]
# #### Reformat time, date variables and create a Week Day column

# %%
air_quality['Generated Date'] = pd.to_datetime(air_quality['Generated Date'],format='%d/%m/%Y')

# %%
air_quality["Week Day"] = air_quality["Generated Date"].dt.day_name()

# %%
air_quality['Generated Date']= air_quality['Generated Date'].dt.strftime("%d/%m/%y")

# %%
air_quality.head()
# Out:
#                    Station Air Quality  Longitude  Latitude O3 Hour  \
# 0        Barcelona - Sants        Good     2.1331   41.3788     NaN
# 1     Barcelona - Eixample    Moderate     2.1538   41.3853      0h
# 2       Barcelona - Gràcia        Good     2.1534   41.3987      0h
# 3   Barcelona - Ciutadella        Good     2.1874   41.3864      0h
# 4  Barcelona - Vall Hebron        Good     2.1480   41.4261      0h
#
#   O3 Quality  O3 Value NO2 Hour NO2 Quality  NO2 Value PM10 Hour PM10 Quality  \
# 0        NaN       NaN       0h        Good       84.0       NaN          NaN
# 1       Good       1.0       0h    Moderate      113.0        0h         Good
# 2       Good      10.0       0h        Good       73.0       NaN          NaN
# 3       Good       2.0       0h        Good       86.0       NaN          NaN
# 4       Good       7.0       0h        Good       69.0       NaN          NaN
#
#    PM10 Value        Generated   Date Time Generated Date Generated Time  \
# ...

# %% [markdown]
# ### Droping column Latitude, Longitude and Genrated

# %%
air_quality=air_quality.drop(columns =["Generated","Latitude","Longitude"])
air_quality
# Out:
#                        Station Air Quality O3 Hour O3 Quality  O3 µg/m3  \
# 0            Barcelona - Sants        Good     NaN        NaN       NaN
# 1         Barcelona - Eixample    Moderate      0h       Good       1.0
# 2           Barcelona - Gràcia        Good      0h       Good      10.0
# 3       Barcelona - Ciutadella        Good      0h       Good       2.0
# 4      Barcelona - Vall Hebron        Good      0h       Good       7.0
# ...                        ...         ...     ...        ...       ...
# 5739    Barcelona - Ciutadella        Good     22h       Good      10.0
# 5740   Barcelona - Vall Hebron        Good     22h       Good      32.0
# 5741   Barcelona - Palau Reial        Good     22h       Good      40.0
# 5742      Barcelona - Poblenou        Good     NaN        NaN       NaN
# 5743  Barcelona - Observ Fabra        Good     22h       Good      64.0
#
#      NO2 Hour NO2 Quality  NO2 µg/m3 PM10 Hour PM10 Quality  PM10 µg/m3  \
# ...

# %% [markdown]
# ### Cleaning colum Station to remove Barcelona

# %%
air_quality["Station"] = air_quality["Station"].str.replace('Barcelona - ', "")

# %%
air_quality
# Out:
#            Station Air Quality O3 Hour O3 Quality  O3 µg/m3 NO2 Hour  \
# 0            Sants        Good     NaN        NaN       NaN       0h
# 1         Eixample    Moderate      0h       Good       1.0       0h
# 2           Gràcia        Good      0h       Good      10.0       0h
# 3       Ciutadella        Good      0h       Good       2.0       0h
# 4      Vall Hebron        Good      0h       Good       7.0       0h
# ...            ...         ...     ...        ...       ...      ...
# 5739    Ciutadella        Good     22h       Good      10.0      22h
# 5740   Vall Hebron        Good     22h       Good      32.0      22h
# 5741   Palau Reial        Good     22h       Good      40.0      22h
# 5742      Poblenou        Good     NaN        NaN       NaN      22h
# 5743  Observ Fabra        Good     22h       Good      64.0      22h
#
#      NO2 Quality  NO2 µg/m3 PM10 Hour PM10 Quality  PM10 µg/m3   Date Time  \
# ...

# %%
air_quality['Station'].unique()
# Out:
# array(['Sants', 'Eixample', 'Gràcia', 'Ciutadella', 'Vall Hebron',
#        'Palau Reial', 'Poblenou', 'Observ Fabra'], dtype=object)

# %% [markdown]
# ### Drop duplicates

# %%
air_quality.drop_duplicates(keep=False,inplace=True)

# %%
air_quality
# Out:
#            Station Air Quality O3 Hour O3 Quality  O3 µg/m3 NO2 Hour  \
# 0            Sants        Good     NaN        NaN       NaN       0h
# 1         Eixample    Moderate      0h       Good       1.0       0h
# 2           Gràcia        Good      0h       Good      10.0       0h
# 3       Ciutadella        Good      0h       Good       2.0       0h
# 4      Vall Hebron        Good      0h       Good       7.0       0h
# ...            ...         ...     ...        ...       ...      ...
# 5739    Ciutadella        Good     22h       Good      10.0      22h
# 5740   Vall Hebron        Good     22h       Good      32.0      22h
# 5741   Palau Reial        Good     22h       Good      40.0      22h
# 5742      Poblenou        Good     NaN        NaN       NaN      22h
# 5743  Observ Fabra        Good     22h       Good      64.0      22h
#
#      NO2 Quality  NO2 µg/m3 PM10 Hour PM10 Quality  PM10 µg/m3   Date Time  \
# ...

# %% [markdown]
# ### What we do with the missing values?

# %% [markdown]
# #### NaN in variables related with time

# %% [markdown]
# ##### Check all variables related to time together

# %%
hour_columns = air_quality[['Station','O3 Hour','NO2 Hour','PM10 Hour','Generated Date','Generated Time']]

# %%
hour_columns.head(50)
#we could just pick one column with the generated time
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-f7b9e62c4ddd> in <module>
# ----> 1 hour_columns.head(50)
#       2 #we could just pick one column with the generated time
#
# NameError: name 'hour_columns' is not defined

# %% [markdown]
# We decide to keep just one column for the time.

# %% [markdown]
# ##### Delete columns of the hour taken the measure and keep the generated time

# %%
air_quality=air_quality.drop(columns =['O3 Hour','NO2 Hour','PM10 Hour'])
air_quality
# Out:
#            Station Air Quality O3 Quality  O3 µg/m3 NO2 Quality  NO2 µg/m3  \
# 0            Sants        Good        NaN       NaN        Good       84.0
# 1         Eixample    Moderate       Good       1.0    Moderate      113.0
# 2           Gràcia        Good       Good      10.0        Good       73.0
# 3       Ciutadella        Good       Good       2.0        Good       86.0
# 4      Vall Hebron        Good       Good       7.0        Good       69.0
# ...            ...         ...        ...       ...         ...        ...
# 5739    Ciutadella        Good       Good      10.0        Good       57.0
# 5740   Vall Hebron        Good       Good      32.0        Good       31.0
# 5741   Palau Reial        Good       Good      40.0        Good       20.0
# 5742      Poblenou        Good        NaN       NaN        Good       70.0
# 5743  Observ Fabra        Good       Good      64.0        Good       21.0
#
# ...

# %% [markdown]
# #### Checking again our NaN table
#
# I am gonna check if it is possible to measure the daily mean of each pollutant, per station. If so, we will be able to replace those with this value. But this is not possible as we have no measure for any day in the month for certain pollutants in certain stations.

# %%
#missing values in station x variable
nan_sants=air_quality[air_quality["Station"]=="Sants"].isnull().sum()
nan_eixample=air_quality[air_quality["Station"]=='Eixample'].isnull().sum()
nan_gracia=air_quality[air_quality["Station"]=='Gràcia'].isnull().sum()
nan_ciutadella=air_quality[air_quality["Station"]=='Ciutadella'].isnull().sum()
nan_valldhebron=air_quality[air_quality["Station"]=='Vall Hebron'].isnull().sum()
nan_palaureial=air_quality[air_quality["Station"]=='Palau Reial'].isnull().sum()
nan_poblenou=air_quality[air_quality["Station"]=='Poblenou'].isnull().sum()
nan_fabra=air_quality[air_quality["Station"]=='Observ Fabra'].isnull().sum()

# %%
nan_x_station= [nan_sants,nan_eixample,nan_gracia,nan_ciutadella,nan_valldhebron,nan_palaureial,nan_poblenou,nan_fabra]

# %%
stations = list(air_quality["Station"].unique())

# %%
nan_matrix_x_column_x_station= pd.concat(nan_x_station, axis=1)

# %%
nan_matrix_x_column_x_station.columns=stations
nan_matrix_x_column_x_station = nan_matrix_x_column_x_station.drop("Station")

# %%
nan_matrix_x_column_x_station =nan_matrix_x_column_x_station.transpose()
nan_matrix_x_column_x_station
# Out:
#               Air Quality  O3 Quality  O3 µg/m3  NO2 Quality  NO2 µg/m3  \
# Sants                  47         718       718           47         47
# Eixample                0          73        73           74         74
# Gràcia                 66          74        74           74         74
# Ciutadella             17          17        17           17         17
# Vall Hebron             2           7         7            7          7
# Palau Reial             5          17        17           17         17
# Poblenou               16         718       718           29         29
# Observ Fabra            8          19        19           19         19
#
#               PM10 Quality  PM10 µg/m3  Date Time  Generated Date  \
# Sants                  718         718          0               0
# Eixample                 0           0          0               0
# Gràcia                 507         507          0               0
# ...
